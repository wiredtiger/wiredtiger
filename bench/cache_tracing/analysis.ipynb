# %%
from matplotlib import pyplot as plt
import numpy as np

#keys = np.loadtxt('../../build/medium-btree.csv')
keys = np.loadtxt('../../build/medium-btree-zipfian.csv')

# %%
plt.hist(keys, 100, range=(0, 100000))
plt.show()
